# %% [markdown]
# <a href="https://colab.research.google.com/github/bosunKwak/Brno_Machine-Learning/blob/main/python_for_ML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# x = np.linspace(0,10,100)
x = np.linspace(0,10,4)
y = x*x

plt.figure()
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0,3,10)
y1 = x
y2 = x**0.5

plt.figure()
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlim(0.5,3.0)
plt.ylim(0.5,3.0)
plt.title("My glorious plot")
plt.show()

# %%
x = np.linspace(0,3,10)
np.sin(x)
# Out:
# array([0.        , 0.3271947 , 0.6183698 , 0.84147098, 0.9719379 ,
#        0.99540796, 0.90929743, 0.72308588, 0.45727263, 0.14112001])

# %%
np.cos(x)
# Out:
# array([ 1.        ,  0.94495695,  0.78588726,  0.54030231,  0.23523757,
#        -0.09572355, -0.41614684, -0.69075814, -0.88932657, -0.9899925 ])

# %%
x =  np.linspace(0,1.6,30)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure()
plt.plot(y1,y2)
plt.axis('equal')
plt.show()

# %%
x =  np.linspace(0,1.6,30)
y1 = np.sin(x)
y2 = np.cos(x)
y= np.stack([y1,y2])

plt.figure()
plt.scatter(y[0],y[1])
plt.axis('equal')
plt.show()

# %%
x =  np.linspace(0,1.6,30)
y1 = np.sin(x)
y2 = np.cos(x)
y= np.stack([y1,y2])

y_small = y*0.3
y_shifted = y+1
y_shifted_up = y+np.array([0.0,1.0])[:,None]

# A = np.array([[0,2],[1,0]])
A = np.array([[0.7,0.7],[-0.7,0.7]])
print(A)

y_new = A@y

plt.figure()

plt.scatter(y[0],y[1])
plt.scatter(y_small[0],y_small[1])
plt.scatter(y_shifted[0],y_shifted[1])
plt.scatter(y_shifted_up[0],y_shifted_up[1])
plt.scatter(y_new[0],y_new[1])

plt.axis('equal')
plt.show()
# Out:
# [[ 0.7  0.7]
#  [-0.7  0.7]]
